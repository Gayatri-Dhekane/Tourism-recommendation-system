# %% [markdown]
# # Group Recommender

# %%
import pandas as pd
import numpy as np

#Import data 
grp_df = pd.read_csv('group.csv')

#Print the top data
grp_df.head()
# Out:
#    grp_id                 grp_name grp_description  \
# 0       1  Ahmadnagar hill station               A
# 1       2        Ahmadnagar temple               B
# 2       3    Birbhum natural beuty               C
# 3       4             Latur island               D
# 4       5        beautiful beaches               E
#
#                                             grp_type       city         state
# 0  Points of Interest & Landmarks  Architectural ...  Ahmadnagar  Maharashtra
# 1        Points of Interest & Landmarks  Scenic Driv  Ahmadnagar  Maharashtra
# 2                                    Religious Sites     Birbhum  West Bengal
# 3                            Amusement & Theme Parks       Latur  Maharashtra
# 4                            Amusement & Theme Parks   Ahmadabad      Gujarat

# %%
place_df = pd.read_csv('topp100.csv')

#Print the top data
place_df.head()
# Out:
#                          Name  \
# 0              1. Qutub Minar
# 1             2. Marine Drive
# 2  3. ISKCON Temple Bangalore
# 3         4. VGP Snow Kingdom
# 4         5. Ramoji Film City
#
#                                                 type  \
# 0  Points of Interest & Landmarks • Architectural...
# 1     Points of Interest & Landmarks • Scenic Drives
# 2                                    Religious Sites
# 3                            Amusement & Theme Parks
# 4                            Amusement & Theme Parks
#
#                                                image No of ratings  \
# 0  https://dynamic-media-cdn.tripadvisor.com/medi...        13,185
# 1  https://dynamic-media-cdn.tripadvisor.com/medi...         8,181
# 2  https://dynamic-media-cdn.tripadvisor.com/medi...         4,811
# 3  https://dynamic-media-cdn.tripadvisor.com/medi...           643
# 4  https://dynamic-media-cdn.tripadvisor.com/medi...         4,174
#
#    average rating                                              about  \
# 0             4.5  Construction on this sandstone minaret was beg...
# 1             4.5  Bordering the Arabian Sea, this famous road is...
# 2             4.5  ISKCON Sri Radha Krishna temple was inaugurate...
# 3             5.0  Indoor attraction featuring manmade snow, sled...
# 4             4.5  Visitors can learn all about the local film in...
#
#                                              address
# 0       Qutb Minar, Mehrauli, New Delhi 110030 India
# 1                    Mumbai,Maharashtra 400002 India
# 2  Chord Road Hare Krishna Hill, Bengaluru 560010...
# 3  East Coast Road Injambakkam, Chennai (Madras) ...
# 4  Ramoji FIlm City Hayatnagar Mandal, Ranga Redd...

# %%
Grp_id=1
df_new = grp_df[grp_df['grp_id'] == Grp_id]

# %%
#grp_type1=df_new['grp_type']
grp_type1=df_new['grp_type']
print(grp_type1)
grp_type1.to_string()
# Out:
# 0    Points of Interest & Landmarks  Architectural ...
# Name: grp_type, dtype: object

# %%
#Import TfIdfVectorizer from the scikit-learn library
from sklearn.feature_extraction.text import TfidfVectorizer
# Import linear_kernel to compute the dot product
from sklearn.metrics.pairwise import linear_kernel

# %%
# Function that takes in user profile(title) as input and gives recommendations 

def content_recommender(place_df=place_df):
    tfidf = TfidfVectorizer(stop_words='english')
    #df2 = {'type': grp_type1}
    #df4 = pd.DataFrame(df2)
    place_df.loc[len(place_df.index)] = {'type': grp_type1} 
    #print(df4.head())
    #place_df.append(df4, ignore_index = True)
    print(place_df.shape)
    #Construct the required TF-IDF matrix by applying the fit_transform method on the combcol feature
    tfidf_matrix = tfidf.fit_transform(place_df['type'])

 
    #Output the shape of tfidf_matrix
    print(tfidf_matrix.shape)
    # Compute the cosine similarity matrix
    cosine_sim = linear_kernel(tfidf_matrix, tfidf_matrix)
   
  
  
    
  

    # Get the pairwsie similarity scores of all group_details with that user profile
    # And convert it into a list of tuples as described above
    sim_scores = list(enumerate(cosine_sim[-1]))

    # Sort the groups based on the cosine similarity scores
    sim_scores = sorted(sim_scores, key=lambda x: x[1], reverse=True)

    # Get the scores of the 10 most similar groups. Ignore the first group.
    sim_scores = sim_scores[1:11]

    # Get the group indices
    group_indices = [i[0] for i in sim_scores]

    # Return the top 10 most similar movies
    return place_df['Name'].iloc[group_indices]

# %%
print(content_recommender())
# Out:
# (101, 7)
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# <ipython-input-113-6cfbb7110fa6> in <module>
# ----> 1 print(content_recommender())
#       2
#       3
#       4
#       5
#
# <ipython-input-112-5d9f1cfb82f8> in content_recommender(place_df)
#      10     print(place_df.shape)
#      11     #Construct the required TF-IDF matrix by applying the fit_transform method on the combcol feature
# ---> 12     tfidf_matrix = tfidf.fit_transform(place_df['type'])
#      13
#      14
#
# F:\Python Stuff\lib\site-packages\sklearn\feature_extraction\text.py in fit_transform(self, raw_documents, y)
#    1848         """
#    1849         self._check_params()
# -> 1850         X = super().fit_transform(raw_documents)
#    1851         self._tfidf.fit(X)
#    1852         # X is already a transformed view of raw_documents so
#
# F:\Python Stuff\lib\site-packages\sklearn\feature_extraction\text.py in fit_transform(self, raw_documents, y)
#    1201         max_features = self.max_features
#    1202
# -> 1203         vocabulary, X = self._count_vocab(raw_documents,
#    1204                                           self.fixed_vocabulary_)
#    1205
#
# F:\Python Stuff\lib\site-packages\sklearn\feature_extraction\text.py in _count_vocab(self, raw_documents, fixed_vocab)
#    1113         for doc in raw_documents:
#    1114             feature_counter = {}
# -> 1115             for feature in analyze(doc):
#    1116                 try:
#    1117                     feature_idx = vocabulary[feature]
#
# F:\Python Stuff\lib\site-packages\sklearn\feature_extraction\text.py in _analyze(doc, analyzer, tokenizer, ngrams, preprocessor, decoder, stop_words)
#     102     else:
#     103         if preprocessor is not None:
# --> 104             doc = preprocessor(doc)
#     105         if tokenizer is not None:
#     106             doc = tokenizer(doc)
#
# F:\Python Stuff\lib\site-packages\sklearn\feature_extraction\text.py in _preprocess(doc, accent_function, lower)
#      67     """
#      68     if lower:
# ---> 69         doc = doc.lower()
#      70     if accent_function is not None:
#      71         doc = accent_function(doc)
#
# F:\Python Stuff\lib\site-packages\pandas\core\generic.py in __getattr__(self, name)
#    5463             if self._info_axis._can_hold_identifiers_and_holds_name(name):
#    5464                 return self[name]
# -> 5465             return object.__getattribute__(self, name)
#    5466
#    5467     def __setattr__(self, name: str, value) -> None:
#
# AttributeError: 'Series' object has no attribute 'lower'
